# %%
# Data Imports and Inspector

# %%
from pathlib import Path

import pandas as pd

# Folder holding one exported CSV per listener
DATA_DIR = Path("data")

# Encodings to try in order; utf-8-sig also strips the BOM some exports have
ENCODINGS = ["utf-8-sig", "utf-16", "cp1252", "latin-1"]


def read_csv_any_encoding(path):
    """Read a CSV, trying each encoding until one works."""
    for encoding in ENCODINGS:
        try:
            return pd.read_csv(path, encoding=encoding)
        except (UnicodeError, pd.errors.ParserError):
            # Wrong encoding for this file, try the next one
            continue
    raise ValueError(f"Could not read {path} with any of {ENCODINGS}")


# Load every CSV in the data folder and tag its rows with the listener
frames = []
for path in sorted(DATA_DIR.glob("*.csv")):
    df = read_csv_any_encoding(path)
    # Listener name is the first word of the file name,
    # e.g. "Logan Exported Data.csv" -> "Logan"
    df["Listener"] = path.stem.split()[0]
    frames.append(df)

# Stack all listeners into one DataFrame
data = pd.concat(frames, ignore_index=True)

# Quick sanity check: total size and rows per listener
print(data.shape)
print(data["Listener"].value_counts())
data.head()
# Out:
# (3197, 25)
# Listener
# Amadou    1663
# Logan     1534
# Name: count, dtype: int64
#                               Track URI         Track Name  \
# 0  spotify:track:6kWxIqQDsKFYCJGbU4AjCX    Hardest To Love
# 1  spotify:track:5Y77SQxEr1eiofPeUTPHxM                You
# 2  spotify:track:1mhVXWduD8ReDwusfaHNwU  Tell Your Friends
# 3  spotify:track:058gdiBln6OADguG08GOaU                Tru
# 4  spotify:track:6n3HGiq4v35D6eFOSwqYuo      Teenage Fever
#
#                   Album Name   Artist Name(s) Release Date  Duration (ms)  \
# 0                After Hours       The Weeknd   2020-03-20         211400
# 1                Street Love  Lloyd;Lil Wayne   2007-02-12         273133
# 2  Beauty Behind The Madness       The Weeknd   2015-08-28         334333
# 3                   TRU - LP            Lloyd   2018-08-31         255640
# 4                  More Life            Drake   2017-03-18         219692
#
#    Popularity  Explicit                   Added By              Added At  ...  \
# 0          68      True  tcgbb1ix1h1h974y7pakbtpr2  2026-09-01T20:30:03Z  ...
# 1          86     False  tcgbb1ix1h1h974y7pakbtpr2  2026-09-01T20:30:03Z  ...
# 2          71      True  tcgbb1ix1h1h974y7pakbtpr2  2026-09-01T20:30:03Z  ...
# 3          64      True  tcgbb1ix1h1h974y7pakbtpr2  2026-09-01T20:30:03Z  ...
# 4          84      True  tcgbb1ix1h1h974y7pakbtpr2  2026-09-01T20:30:03Z  ...
#
#   Loudness Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0   -7.847  0.0       0.0713        0.0909          0.000088     0.125
# 1   -6.008  0.0       0.4720        0.1020          0.000000     0.297
# 2  -11.091  0.0       0.0425        0.2650          0.000000     0.181
# 3   -5.877  1.0       0.0670        0.1190          0.000000     0.117
# 4  -10.330  0.0       0.0846        0.1110          0.017200     0.115
#
#    Valence    Tempo  Time Signature  Listener
# 0    0.111   81.898             4.0    Amadou
# 1    0.706  130.210             5.0    Amadou
# 2    0.309   74.640             4.0    Amadou
# 3    0.135  143.358             4.0    Amadou
# 4    0.144   97.040             4.0    Amadou
#
# [5 rows x 25 columns]
